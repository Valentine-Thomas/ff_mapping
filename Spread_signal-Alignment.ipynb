# %% [markdown]
# alignment in time and space: done after correction and filtering
# ;before calculating other parameters

# %%
import numpy as np
import os
import pandas as pd
from trajalign.traj import Traj
from trajalign.average import load_directory

# %%
# get all traj in a list and align => see pretreatment BUT with only 0,1,2,3 as columns 
#files containing fusion events folder
path='/mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/' 

files = ['Prm1'] 

#color of h-/h+ spatial marker
RefM= '_B' #'_B' if POI in h+ cell, '_R' if POI in h- cell
RefP= '_R' #'_R' if POI in h+ cell, '_B' if POI in h- cell
    
def replicats_nb(POI):
    rep_list = [ folder for folder in os.listdir(path+POI) if 'Rep_' in folder ]
    r= len(rep_list)
    return r

def get_data(POI,rep) :
    directory_rep = os.listdir( path+POI+'/Rep_'+str(rep+1)+'/trajectories') #absolute path of directory to charge data from
    f = [ folder for folder in directory_rep if 'cell_' in folder ] # 'cell_' -> folder name to list
    return f 

#determin fusion frame based on cytoplasmic fluorescence intensity
def fusion_frame (m_c):
    for x in m_c:
        n=len(x)   # number of frames
        U=np.empty( ((n-2),2) ) # creation of an empty array of n-2 lines and 2 columns
        
            
        for tau in range ((n-2)):  
# construction of the model for frame = x            
            m1 = np.mean(x.f()[0:tau])   
            m2 = np.mean(x.f()[(tau+1):n])
            m = np.array([m1] * tau + [m2]* (n-tau)) # use np.array because python can't substract list
            e = x.f() - m                           # substract theorical model from data
            U[tau,0] = x.frames()[tau]               # first column of matrix = frame number
            U[tau,1] = np.sum(e**2)                  # second column of matrix = sum of square errors 
        pos= np.argmin( U[:,1])              # get position of frame corresponding to mimimum sum of squared errors
        f_f=x.frames()[pos]              #get frame of fusion
        f_f= f_f-1   #correct for diff frame numeration PT/Fiji
        
    return f_f 

#align trajectory such that centermass trajectory from h- cell = origin 
def fusion_axis( t_l ) :
	# input a trajectory list t_l

	# search for the red trajectory, and compute its
	# center of mass
    for t in t_l :
	
		# select the blue trajectory
        if RefM in t.annotations()[ 'file' ] :
			# compute the center of mass of the trajctory
            r = t.center_mass()

	# subtract the center of mass of the red trajectory
	# from all trajectories in the cell. The center of mass
	# of the red trajectory will definethe origin of the x-y
	# plane
    for t in t_l :
		
		# translate all the trajectories accordingly
        t.translate( -r )
		# normalise the flurescence intensities between 0 and 1
        t.norm_f() # normalise between 0 and 1

	# compute the center of mass of the blue trajectory.
	# As the trajectory has been now translated by r, 
	# its center of mass defines the vector of the cell
	# fusion reference frame defined by the two center of
	# mass positions of the Myo52-RFP and Myo52-BFP
    for t in t_l :

		# select the red trajectory
        if RefP in t.annotations()[ 'file' ] :
			# compute the center of mass of the trajctory
            b = t.center_mass()
			# normalise the vector to a unit vector
            v = [ i / np.sqrt( b[ 0 ] ** 2 + b[ 1 ] ** 2 ) for i in b ]

    return t_l , v

# %%
n= len(files) 
Rep= []
for i in range(n):
    r=replicats_nb(files[i])
    Rep.append(r)
folders=[[] for _ in range(n)] #lists for POI rep folders => each subset will contains n subset for each replicat

for i in range(len(Rep)):
    folders[i]=[[] for _ in range(Rep[i])] 

# list all cell_ folders for each POI 

for i in range(n) :
    for r in range(Rep[i]):
        f=get_data(files[i],r)
        folders[i][r]= f 
        
# get trajectories for each fusions sites of each POI
# trajectory classes => frames, coord = centroid coord; coord_err= [0]mu20 et [1] mu02; f_err= mu11 

ct=0
for f in folders:
    r=1
    file_path=os.path.join(path,files[ct])
    for rep in f:
        id=0
        replicat='Rep_'+str(r)
        event_path=os.path.join(file_path,replicat)+'/trajectories/'
        print(event_path)

        for event in rep: 
            t_br = load_directory(os.path.join(event_path,event), pattern= 'Traj_' , comment_char = '#' , frames = 0 , coord = ( 1 , 2 ) , f = 3 ,coord_unit = 'pxl' )
            for tr in t_br:
                if RefM in tr.annotations()[ 'file' ] :
                    tr.save(os.path.join(event_path,event,'Trajectory_B.txt'))
                elif RefP in tr.annotations()[ 'file' ] :
                    tr.save(os.path.join(event_path,event,'Trajectory_R.txt'))
                    
                    
            m_c = load_directory(os.path.join(event_path,event), pattern= '.csv',  comment_char = '#' ,sep= ',', frames = 0 , f = 1 )
            t_l = load_directory(os.path.join(event_path,event), pattern= 'Trajectory' , comment_char = '#' , frames = 0 , coord = ( 1 , 2 ) , f = 3 ,coord_unit = 'pxl' )   
            f_f = fusion_frame (m_c)
            for c in m_c:
                centered_c= c.frames()-f_f
                c.input_values('frames',centered_c)
                c.time (3, min) 
                c.norm_f() 
        #center trajectory in time 
            for t in t_l:
                centered_f= t.frames()-f_f     #remove f_f from frame number to center around fusion time (=0)
                t.input_values('frames',centered_f) #replace fram number in trajectories by centered frame number
                scaled_t= t.coord()/ (15.4321)
                t.input_values('coord', scaled_t)   # scale: 15.4321 px/µm, get coordonated as µm
                t.time (3, min)                       # enter time value for each point of the trajectory
            t_l_0 , v = fusion_axis( t_l )

	# rotate the trajectory, so that the fusion axis is 
	# aligned with x positive axis
            angle = np.sign( v[ 0 ] ) * np.arcsin( v[ 1 ] ) - ( np.sign( v[ 0 ] ) - 1 ) * np.pi / 2 
	# add angle offset (we want to see red on the left of the plot, blue on the right)
            angle = angle + np.pi 

	# rotate each trajectory in the trajectory list + save it in new folder 
            os.makedirs(path+files[ct]+'/aligned_trajectories/Rep_'+str(r)+'/cell_%03d/' %id, exist_ok=True)
            print(path+files[ct]+'/aligned_trajectories/Rep_'+str(r)+'/cell_%03d/' %id)
            for t_0 in t_l_0 :
                t_0.rotate( -angle )
                if RefM in t_0.annotations()[ 'file' ] :
                    t_0.save(file_path+'/aligned_trajectories/Rep_'+str(r)+'/cell_%03d/Traj_M.txt'%id)
                elif RefP in t_0.annotations()[ 'file' ] :
                    t_0.save(file_path+'/aligned_trajectories/Rep_'+str(r)+'/cell_%03d/Traj_P.txt'%id)
                else :
                    t_0.save(file_path+'/aligned_trajectories/Rep_'+str(r)+'/cell_%03d/Traj_POI.txt'%id)
                    print(file_path+'/aligned_trajectories/Rep_'+str(r)+'/cell_%03d/Traj_POI.txt'%id)
        
            id+=1
        r+=1
    ct+=1
# Out:
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/Rep_1/trajectories/
# 1-Traj_01_B-01.txt
# 1-Traj_01_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 1-mCherry_01.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_000/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_000/Traj_POI.txt
# 1-Traj_03_B-01.txt
# 1-Traj_03_R-03.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 1-mCherry_03.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_001/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_001/Traj_POI.txt
# 1-Traj_04_B-01.txt
# 1-Traj_04_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 1-mCherry_04.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_002/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_002/Traj_POI.txt
# 1-Traj_05_B-03.txt
# 1-Traj_05_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 1-mCherry_05.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_003/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_003/Traj_POI.txt
# 1-Traj_08_B-02.txt
# 1-Traj_08_R-03.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 1-mCherry_08.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_004/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_004/Traj_POI.txt
# 1-Traj_09_B-01.txt
# 1-Traj_09_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 1-mCherry_09.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_005/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_005/Traj_POI.txt
# 1-Traj_10_B-01.txt
# 1-Traj_10_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 1-mCherry_10.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_006/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_006/Traj_POI.txt
# 1-Traj_11_B-03.txt
# 1-Traj_11_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 1-mCherry_11.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_007/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_007/Traj_POI.txt
# 1-Traj_12_B-03.txt
# 1-Traj_12_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 1-mCherry_12.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_008/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_008/Traj_POI.txt
# 1-Traj_13_B-01.txt
# 1-Traj_13_R-02.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 1-mCherry_13.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_009/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_009/Traj_POI.txt
# 1-Traj_14_B-01.txt
# 1-Traj_14_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 1-mCherry_14.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_010/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_010/Traj_POI.txt
# 1-Traj_15_B-03.txt
# 1-Traj_15_R-01.txt
# /mnt/c/Users/Valentine/Documents/Scripts/notebook/jupyterenv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /mnt/c/Users/Valentine/Documents/Scripts/notebook/jupyterenv/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 1-mCherry_15.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_011/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_011/Traj_POI.txt
# 1-Traj_18_B-02.txt
# 1-Traj_18_R-03.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 1-mCherry_18.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_012/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_012/Traj_POI.txt
# 1-Traj_19_B-01.txt
# 1-Traj_19_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 1-mCherry_19.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_013/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_013/Traj_POI.txt
# 1-Traj_20_B-03.txt
# 1-Traj_20_R-05.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 1-mCherry_20.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_014/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_014/Traj_POI.txt
# 1-Traj_21_B-01.txt
# 1-Traj_21_R-03.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 1-mCherry_21.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_015/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_015/Traj_POI.txt
# 1-Traj_23_B-02.txt
# 1-Traj_23_R-04.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 1-mCherry_23.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_016/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_016/Traj_POI.txt
# 1-Traj_26_B-01.txt
# 1-Traj_26_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 1-mCherry_26.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_017/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_017/Traj_POI.txt
# 1-Traj_27_B-01.txt
# 1-Traj_27_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 1-mCherry_27.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_018/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_018/Traj_POI.txt
# 1-Traj_28_B-01.txt
# 1-Traj_28_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 1-mCherry_28.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_019/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_019/Traj_POI.txt
# 1-Traj_29_B-02.txt
# 1-Traj_29_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 1-mCherry_29.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_020/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_020/Traj_POI.txt
# 1-Traj_31_B-01.txt
# 1-Traj_31_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 1-mCherry_31.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_021/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_021/Traj_POI.txt
# 1-Traj_33_B-01.txt
# 1-Traj_33_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 1-mCherry_33.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_022/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_022/Traj_POI.txt
# 1-Traj_34_B-01.txt
# 1-Traj_34_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 1-mCherry_34.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_023/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_023/Traj_POI.txt
# 1-Traj_35_B-01.txt
# 1-Traj_35_R-04.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 1-mCherry_35.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_024/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_024/Traj_POI.txt
# 1-Traj_36_B-05.txt
# 1-Traj_36_R-02.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 1-mCherry_36.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_025/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_025/Traj_POI.txt
# 2-Traj_03_B-01.txt
# 2-Traj_03_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 2-mCherry_03.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_026/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_026/Traj_POI.txt
# 2-Traj_04_B-06.txt
# 2-Traj_04_R-04.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 2-mCherry_04.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_027/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_027/Traj_POI.txt
# 2-Traj_05_B-05.txt
# 2-Traj_05_R-04.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 2-mCherry_05.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_028/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_028/Traj_POI.txt
# 2-Traj_06_B-01.txt
# 2-Traj_06_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 2-mCherry_06.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_029/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_029/Traj_POI.txt
# 2-Traj_07_B-03.txt
# 2-Traj_07_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 2-mCherry_07.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_030/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_030/Traj_POI.txt
# 2-Traj_08_B-01.txt
# 2-Traj_08_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 2-mCherry_08.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_031/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_031/Traj_POI.txt
# 2-Traj_09_B-03.txt
# 2-Traj_09_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 2-mCherry_09.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_032/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_032/Traj_POI.txt
# 2-Traj_10_B-01.txt
# 2-Traj_10_R-02.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 2-mCherry_10.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_033/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_033/Traj_POI.txt
# 2-Traj_11_B-01.txt
# 2-Traj_11_R-04.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 2-mCherry_11.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_034/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_034/Traj_POI.txt
# 2-Traj_14_B-01.txt
# 2-Traj_14_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 2-mCherry_14.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_035/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_035/Traj_POI.txt
# 2-Traj_15_B-01.txt
# 2-Traj_15_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 2-mCherry_15.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_036/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_036/Traj_POI.txt
# 2-Traj_16_B-01.txt
# 2-Traj_16_R-03.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 2-mCherry_16.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_037/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_037/Traj_POI.txt
# 3-Traj_01_B-01.txt
# 3-Traj_01_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 3-mCherry_01.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_038/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_038/Traj_POI.txt
# 3-Traj_03_B-01.txt
# 3-Traj_03_R-02.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 3-mCherry_03.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_039/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_039/Traj_POI.txt
# 3-Traj_04_B-01.txt
# 3-Traj_04_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 3-mCherry_04.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_040/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_040/Traj_POI.txt
# 3-Traj_05_B-01.txt
# 3-Traj_05_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 3-mCherry_05.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_041/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_041/Traj_POI.txt
# 3-Traj_06_B-01.txt
# 3-Traj_06_R-04.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 3-mCherry_06.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_042/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_042/Traj_POI.txt
# 3-Traj_07_B-03.txt
# 3-Traj_07_R-03.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 3-mCherry_07.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_043/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_043/Traj_POI.txt
# 3-Traj_08_B-01.txt
# 3-Traj_08_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 3-mCherry_08.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_044/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_044/Traj_POI.txt
# 3-Traj_09_B-02.txt
# 3-Traj_09_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 3-mCherry_09.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_045/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_045/Traj_POI.txt
# 3-Traj_10_B-01.txt
# 3-Traj_10_R-06.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 3-mCherry_10.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_046/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_046/Traj_POI.txt
# 3-Traj_11_B-01.txt
# 3-Traj_11_R-03.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 3-mCherry_11.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_047/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_047/Traj_POI.txt
# 3-Traj_13_B-01.txt
# 3-Traj_13_R-04.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 3-mCherry_13.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_048/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_048/Traj_POI.txt
# 3-Traj_14_B-04.txt
# 3-Traj_14_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 3-mCherry_14.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_049/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_049/Traj_POI.txt
# 3-Traj_15_B-02.txt
# 3-Traj_15_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 3-mCherry_15.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_050/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_050/Traj_POI.txt
# 3-Traj_16_B-01.txt
# 3-Traj_16_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 3-mCherry_16.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_051/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_051/Traj_POI.txt
# 3-Traj_17_B-01.txt
# 3-Traj_17_R-05.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 3-mCherry_17.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_052/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_052/Traj_POI.txt
# 3-Traj_18_B-03.txt
# 3-Traj_18_R-04.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 3-mCherry_18.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_053/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_053/Traj_POI.txt
# 3-Traj_19_B-02.txt
# 3-Traj_19_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 3-mCherry_19.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_054/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_054/Traj_POI.txt
# 3-Traj_21_B-01.txt
# 3-Traj_21_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 3-mCherry_21.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_055/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_055/Traj_POI.txt
# 3-Traj_22_B-03.txt
# 3-Traj_22_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 3-mCherry_22.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_056/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_056/Traj_POI.txt
# 4-Traj_01_B-02.txt
# 4-Traj_01_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 4-mCherry_01.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_057/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_057/Traj_POI.txt
# 4-Traj_02_B-01.txt
# 4-Traj_02_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 4-mCherry_02.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_058/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_058/Traj_POI.txt
# 4-Traj_03_B-03.txt
# 4-Traj_03_R-02.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 4-mCherry_03.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_059/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_059/Traj_POI.txt
# 4-Traj_04_B-03.txt
# 4-Traj_04_R-03.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 4-mCherry_04.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_060/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_060/Traj_POI.txt
# 4-Traj_05_B-02.txt
# 4-Traj_05_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 4-mCherry_05.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_061/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_061/Traj_POI.txt
# 4-Traj_06_B-03.txt
# 4-Traj_06_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 4-mCherry_06.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_062/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_062/Traj_POI.txt
# 4-Traj_07_B-01.txt
# 4-Traj_07_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 4-mCherry_07.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_063/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_063/Traj_POI.txt
# 4-Traj_08_B-01.txt
# 4-Traj_08_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 4-mCherry_08.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_064/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_064/Traj_POI.txt
# 4-Traj_09_B-01.txt
# 4-Traj_09_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 4-mCherry_09.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_065/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_065/Traj_POI.txt
# 4-Traj_10_B-01.txt
# 4-Traj_10_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 4-mCherry_10.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_066/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_066/Traj_POI.txt
# 4-Traj_11_B-04.txt
# 4-Traj_11_R-03.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 4-mCherry_11.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_067/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_067/Traj_POI.txt
# 4-Traj_12_B-01.txt
# 4-Traj_12_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 4-mCherry_12.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_068/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_068/Traj_POI.txt
# 4-Traj_13_B-02.txt
# 4-Traj_13_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 4-mCherry_13.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_069/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_069/Traj_POI.txt
# 4-Traj_14_B-01.txt
# 4-Traj_14_R-02.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 4-mCherry_14.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_070/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_070/Traj_POI.txt
# 4-Traj_15_B-01.txt
# 4-Traj_15_R-02.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 4-mCherry_15.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_071/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_071/Traj_POI.txt
# 4-Traj_16_B-01.txt
# 4-Traj_16_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 4-mCherry_16.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_072/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_072/Traj_POI.txt
# 4-Traj_17_B-01.txt
# 4-Traj_17_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 4-mCherry_17.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_073/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_073/Traj_POI.txt
# 4-Traj_18_B-01.txt
# 4-Traj_18_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 4-mCherry_18.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_074/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_074/Traj_POI.txt
# 4-Traj_19_B-01.txt
# 4-Traj_19_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 4-mCherry_19.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_075/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_075/Traj_POI.txt
# 4-Traj_20_B-01.txt
# 4-Traj_20_R-03.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 4-mCherry_20.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_076/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_076/Traj_POI.txt
# 4-Traj_21_B-03.txt
# 4-Traj_21_R-02.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 4-mCherry_21.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_077/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_077/Traj_POI.txt
# 5-Traj_01_B-03.txt
# 5-Traj_01_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 5-mCherry_01.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_078/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_078/Traj_POI.txt
# 5-Traj_02_B-03.txt
# 5-Traj_02_R-05.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 5-mCherry_02.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_079/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_079/Traj_POI.txt
# 5-Traj_03_B-01.txt
# 5-Traj_03_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 5-mCherry_03.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_080/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_080/Traj_POI.txt
# 5-Traj_04_B-01.txt
# 5-Traj_04_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 5-mCherry_04.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_081/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_081/Traj_POI.txt
# 5-Traj_05_B-01.txt
# 5-Traj_05_R-01.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 5-mCherry_05.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_082/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_082/Traj_POI.txt
# 5-Traj_07_B-01.txt
# 5-Traj_07_R-05.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# 5-mCherry_07.csv
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# Trajectory_B.txt
# Trajectory_G.txt
# Trajectory_R.txt
#
#  >> load_directory: The 'intensity_normalisation' applied to the trajectories is 'None' <<
#
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_083/
# /mnt/c/Users/Valentine/Documents/Analysis/POI_spread_signal/Prm1/aligned_trajectories/Rep_1/cell_083/Traj_POI.txt
